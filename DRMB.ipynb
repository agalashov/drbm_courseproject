# %%
import numpy as np
import tensorflow as tf
from datetime import date

# %%
# Load MNIST Data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
trX, trY, teX, teY = mnist.train.images, mnist.train.labels, mnist.test.images, mnist.test.labels
valX, valY = mnist.validation.images, mnist.validation.labels
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Model HyperParameters
num_visible = 28*28
num_classes = 10
num_hidden = 500
batch_size = 1
num_epochs = 100
num_batches = np.shape(trX)[0] / batch_size

if np.shape(trX)[0] % batch_size > 0:
    num_batches += 1

# %%
# with tf.device('/gpu:0'):
# DRMB Model
m = np.max([num_hidden, num_classes])
m_sqrt = np.sqrt(m)

# Model inputs
X = tf.placeholder(tf.float32, [None, num_visible])

Y = tf.placeholder(tf.float32, [None, num_classes])

learning_rate = tf.placeholder(tf.float32)

# Model internal parameters
U = tf.Variable(tf.random_uniform([num_hidden, num_classes], minval=-m_sqrt, maxval=m_sqrt), name='hlayer-classes-connections')

W = tf.Variable(tf.random_uniform([num_hidden, num_visible], minval=-m_sqrt, maxval=m_sqrt), name='hlayer-input-connections')

# b = tf.Variable(tf.zeros([num_visible, 1]), name='input-bias')

c = tf.Variable(tf.zeros([num_hidden, 1]), name='hlayer-bias')

d = tf.Variable(tf.zeros([num_classes, 1]), name='classes-bias')

# Batch dimension needed for the equations
#batch_dimension = tf.shape(X)[0]
#batch_normalization = 1.0 / tf.cast(batch_dimension, tf.float32)

batch_normalization = 1.0 / batch_size

# All the classes
Y_all_classes = tf.diag(tf.ones(num_classes, 1))

# U [num_hiden x num_classes] * Y_all_classes [num_classes x num_classes]
# Result : U_all_classes : [batch_dimension x num_hidden x num_classes]
U_all_y = tf.reshape(tf.matmul(U, Y_all_classes), [1, num_hidden, num_classes])

def give_p_all_y_given_x(U_all_y, W, c, d, X):
    # Tensor of shape (None x num_hidden)
    WX = tf.transpose(tf.matmul(W, tf.transpose(X)))
    
#     print S.get_shape()

    # WX + c for all batches
    # Result : O (batch_dimension x num_hidden)
    O = WX + tf.reshape(c, [1, num_hidden])
#     O = WX + tf.tile(tf.reshape(c, [1, num_hidden]), [-1, 1])

    # Extend O on all the classes:
    # Result : O (batch_dimension x num_hidden x num_classes)    
#     O = 
#     O = tf.tile(tf.reshape(O, [-1, num_hidden, 1]), [1, 1, num_classes])

    # Extend U_all_classes for all batches
    # Result : U_all_y_extended (batch_dimension x num_hidden x num_classes)
#     U_all_y_extended
#     U_all_y_extended = tf.tile(tf.reshape(U_all_y, [1, num_hidden, num_classes]), [-1, 1, 1])
    
    # Resulted O:
    # Result: O (batch_dimension x num_hidden x num_classes)
    O = tf.reshape(O, [-1, num_hidden, 1]) + tf.reshape(U_all_y, [1, num_hidden, num_classes])

    # First term in log p(y|x) which is calculated for each x in the batch
    # Result : first_term (batch_dimension x num_classes)
    first_term = tf.transpose(tf.matmul(Y_all_classes, d))
#     first_term = tf.tile(tf.reshape(tf.matmul(Y_all_classes, d), [1, num_classes]), [-1, 1])

    # Second term in log p(y|x) which is calculated for each x in the batch
    # Result : second_term (batch_dimension x num_classes)            
    second_term = tf.reduce_sum(tf.nn.softplus(O), 1)
#     second_term = tf.reduce_sum(tf.nn.softplus(O), 1)

    # Positive part of log p(y|x)  
    # Result: positive_part (batch_dimension x num_classes)
    positive_part = first_term + second_term

    # Use the softmax to calculate the probabilities:
    # Result: p_y_all_given_x (batch_dimension x num_classes)
    p_y_all_given_x = tf.nn.softmax(positive_part)
    
    return WX, O, positive_part, p_y_all_given_x

WX, O_all, positive_part, p_y_all_given_x = give_p_all_y_given_x(U_all_y, W, c, d, X)

# Calculate p(y|x) for concrete x
# Result : p_y_given_x (batch_dimension x 1)
p_y_given_x = tf.reshape(tf.reduce_sum(tf.mul(p_y_all_given_x, Y),1), [-1, 1])

# Training part

# Calculate UY
# Result : U (batch_dimension x num_hidden)
UY = tf.transpose(tf.matmul(U, tf.transpose(Y)))

O = WX + UY

# O_sigma: (batch_dimension x num_hidden)
O_sigma = tf.sigmoid(O)

# O_sigma_all_Y : (batch_dimension x num_hidden x num_classes)
O_sigma_all_Y = tf.sigmoid(O_all)

# O_sigma_all_Y_p : (batch_dimension x num_hidden x num_classes)
# O_sigma_all_Y_p = tf.batch_mul(O_sigma_all_Y, tf.reshape(p_y_all_given_x, 
O_sigma_all_Y_p = tf.mul(O_sigma_all_Y, tf.tile(tf.reshape(p_y_all_given_x, [-1, 1, num_classes]), [1, num_hidden, 1]))                         

# # d_U: (num_hidden x num_classes)
dU_left = tf.matmul(tf.transpose(O_sigma), Y) #tf.matmul(O_sigma, Y)
dU_right = tf.matmul(tf.transpose(tf.reduce_sum(O_sigma_all_Y_p, 2)), Y)# O_sigma_all_Y_p
# dU_left = tf.matmul(tf.transpose(O_sigma), tf.ones([-1, num_classes]))
# dU_right = tf.reduce_sum(O_sigma_all_Y_p, 0)
d_U = batch_normalization * (dU_left - dU_right)
d_U = tf.reshape(d_U, [num_hidden, num_classes])

# d_W : (num_hidden x num_visible)
dW_left = tf.matmul(tf.transpose(O_sigma), X)
dW_right = tf.matmul(tf.transpose(tf.reduce_sum(O_sigma_all_Y_p, 2)), X) 
# dW_right = tf.reduce_sum(tf.batch_matmul(O_sigma_all_Y_p, tf.tile(tf.reshape(X, [-1, num_visible, 1]), [1, 1, num_classes]), adj_y=True), 0)
d_W = batch_normalization * (dW_left - dW_right)
d_W = tf.reshape(d_W, [num_hidden, num_visible])

# d_c : (num_hidden x 1)
dc_left = tf.reduce_sum(O_sigma, 0) #tf.matmul(tf.transpose(O_sigma)) #, tf.ones([-1, 1]))
dc_right = tf.reduce_sum(tf.reduce_sum(O_sigma_all_Y_p, 2), 0)
# dc_right = tf.reduce_sum(tf.reduce_sum(O_sigma_all_Y_p, 2), 
#tf.reshape(tf.reduce_sum(tf.reduce_sum(O_sigma_all_Y_p,0),1), [num_hidden, 1])
d_c = batch_normalization * (dc_left - dc_right)
d_c = tf.reshape(d_c, [num_hidden, 1])

# d_d : (num_classes x 1)
d_d = batch_normalization * (tf.reduce_sum(Y - p_y_all_given_x, 0))
d_d = tf.reshape(d_d, [num_classes, 1])

# updates:
updates = [U.assign_add(learning_rate * d_U), W.assign_add(learning_rate * d_W), c.assign_add(learning_rate * d_c), d.assign_add(learning_rate * d_d)]

# Error classification
# _, _, _, _, predicted_all_y = give_p_all_y_given_x(tf.matmul(U, Y_all_classes), W, c, d, X)

predicted_y = tf.argmax(p_y_all_given_x, 1)
# predicted_y = tf.argmax(predicted_all_y, 1)
ground_truth = tf.argmax(Y, 1)

correct_prediction = tf.equal(predicted_y, ground_truth)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# da = tf.log(p_y_all_given_x)
# loss = -tf.reduce_mean(tf.log(tf.reduce_max(tf.mul(p_y_all_given_x, Y), 1)))

# %%
# Running session
config = tf.ConfigProto(allow_soft_placement = True)
sess = tf.Session(config = config)
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
init = tf.initialize_all_variables()
sess.run(init)

# Add ops to save and restore all the variables.
saver = tf.train.Saver()

# %%
train_accuracies = np.zeros([num_epochs, num_batches + 1])
validation_accuracies = np.zeros([num_epochs, num_batches + 1])
test_accuracies = np.zeros([num_epochs, 1])
today = str(date.today())
print today
# Out:
# 2016-12-09

# %%
# Debugging
for epoch in range(1, num_epochs + 1):
#     sess.run(init)
    j = 1
    for i in range(1, num_batches + 1):
        with tf.device('/gpu:0'):
            tr_x, tr_y = mnist.train.next_batch(batch_size)
            alpha = 0.05
#             alpha = np.exp(0.05)
#             if epoch != 1:
#                 alpha = 0.00005
#             else :
#                 alpha = min(0.00005, 100.0 / i) #0.001 #min(0.01, 20000/i)
            sess.run([updates], feed_dict={X: tr_x, Y: tr_y, learning_rate: alpha})            
            
        if i % 5000 == 0:
            with tf.device('/cpu:0'):                
                train_accuracy = sess.run([accuracy], feed_dict={X: trX, Y: trY})                            
                val_accuracy = sess.run([accuracy], feed_dict={X: valX, Y: valY})            
                
                print 'epoch : ', epoch
                print 'i : ', i
                print 'train_accuracy : ', train_accuracy[0]
                print 'validation_accuracy : ', val_accuracy[0]
                
                save_path = saver.save(sess, "./models/"+today+"_"+str(epoch)+"_"+str(j)+"_model.ckpt")
                print("Model saved in file: %s" % save_path)                
                train_accuracies[epoch - 1][j] = train_accuracy[0]
                validation_accuracies[epoch - 1][j] = val_accuracy[0]
                j = j+1           
    train_acc = sess.run([accuracy], feed_dict={X: trX, Y: trY})      
    val_acc = sess.run([accuracy], feed_dict={X: valX, Y: valY})  
    test_acc = sess.run([accuracy], feed_dict={X: teX, Y: teY})  
    train_accuracies[epoch - 1, 0] = train_acc[0]
    validation_accuracies[epoch - 1, 0] = val_acc[0]
    test_accuracies[epoch - 1, 0] = test_acc[0]
    
    print 'One epoch finished'
    print 'epoch : ', epoch
    print 'train_accuracy : ', train_acc[0]
    print 'validation_accuracy : ', val_acc[0]
    print 'test_accuracy : ', test_acc[0]
    
    save_path = saver.save(sess, "./models/"+today+"_"+str(epoch)+"_"+str(0)+"_model.ckpt")
    print("Model saved in file: %s" % save_path)
# Out:
# epoch :  1
# i :  5000
# train_accuracy :  0.573491
# validation_accuracy :  0.5812
# Model saved in file: ./models/2016-12-09_1_1_model.ckpt
# epoch :  1
# i :  10000
# train_accuracy :  0.689218
# validation_accuracy :  0.6986
# Model saved in file: ./models/2016-12-09_1_2_model.ckpt
# epoch :  1
# i :  15000
# train_accuracy :  0.737018
# validation_accuracy :  0.7426
# Model saved in file: ./models/2016-12-09_1_3_model.ckpt
# epoch :  1
# i :  20000
# train_accuracy :  0.761291
# validation_accuracy :  0.7642
# Model saved in file: ./models/2016-12-09_1_4_model.ckpt
# epoch :  1
# i :  25000
# train_accuracy :  0.785491
# validation_accuracy :  0.7914
# Model saved in file: ./models/2016-12-09_1_5_model.ckpt
# epoch :  1
# i :  30000
# train_accuracy :  0.802346
# validation_accuracy :  0.803
# Model saved in file: ./models/2016-12-09_1_6_model.ckpt
# epoch :  1
# i :  35000
# train_accuracy :  0.821037
# validation_accuracy :  0.8202
# Model saved in file: ./models/2016-12-09_1_7_model.ckpt
# epoch :  1
# i :  40000
# train_accuracy :  0.825837
# validation_accuracy :  0.824
# Model saved in file: ./models/2016-12-09_1_8_model.ckpt
# epoch :  1
# i :  45000
# train_accuracy :  0.834419
# validation_accuracy :  0.8316
# Model saved in file: ./models/2016-12-09_1_9_model.ckpt
# epoch :  1
# i :  50000
# train_accuracy :  0.840146
# validation_accuracy :  0.838
# Model saved in file: ./models/2016-12-09_1_10_model.ckpt
# epoch :  1
# i :  55000
# train_accuracy :  0.847582
# validation_accuracy :  0.8474
# Model saved in file: ./models/2016-12-09_1_11_model.ckpt
# One epoch finished
# epoch :  1
# train_accuracy :  0.847582
# validation_accuracy :  0.8474
# test_accuracy :  0.8378
# Model saved in file: ./models/2016-12-09_1_0_model.ckpt
# epoch :  2
# i :  5000
# train_accuracy :  0.851819
# validation_accuracy :  0.8424
# Model saved in file: ./models/2016-12-09_2_1_model.ckpt
# epoch :  2
# i :  10000
# train_accuracy :  0.868382
# validation_accuracy :  0.8578
# Model saved in file: ./models/2016-12-09_2_2_model.ckpt
# epoch :  2
# i :  15000
# train_accuracy :  0.864473
# validation_accuracy :  0.8554
# Model saved in file: ./models/2016-12-09_2_3_model.ckpt
# epoch :  2
# i :  20000
# train_accuracy :  0.870564
# validation_accuracy :  0.86
# Model saved in file: ./models/2016-12-09_2_4_model.ckpt
# epoch :  2
# i :  25000
# train_accuracy :  0.872946
# validation_accuracy :  0.861
# Model saved in file: ./models/2016-12-09_2_5_model.ckpt
# epoch :  2
# i :  30000
# train_accuracy :  0.87711
# validation_accuracy :  0.8648
# Model saved in file: ./models/2016-12-09_2_6_model.ckpt
# epoch :  2
# i :  35000
# train_accuracy :  0.879964
# validation_accuracy :  0.8684
# Model saved in file: ./models/2016-12-09_2_7_model.ckpt
# epoch :  2
# i :  40000
# train_accuracy :  0.883055
# validation_accuracy :  0.8682
# Model saved in file: ./models/2016-12-09_2_8_model.ckpt
# epoch :  2
# i :  45000
# train_accuracy :  0.888019
# validation_accuracy :  0.8742
# Model saved in file: ./models/2016-12-09_2_9_model.ckpt
# epoch :  2
# i :  50000
# train_accuracy :  0.885182
# validation_accuracy :  0.8724
# Model saved in file: ./models/2016-12-09_2_10_model.ckpt
# epoch :  2
# i :  55000
# train_accuracy :  0.892273
# validation_accuracy :  0.8752
# Model saved in file: ./models/2016-12-09_2_11_model.ckpt
# One epoch finished
# epoch :  2
# train_accuracy :  0.892273
# validation_accuracy :  0.8752
# test_accuracy :  0.8756
# Model saved in file: ./models/2016-12-09_2_0_model.ckpt
# epoch :  3
# i :  5000
# train_accuracy :  0.895746
# validation_accuracy :  0.8776
# Model saved in file: ./models/2016-12-09_3_1_model.ckpt
# epoch :  3
# i :  10000
# train_accuracy :  0.893873
# validation_accuracy :  0.874
# Model saved in file: ./models/2016-12-09_3_2_model.ckpt
# epoch :  3
# i :  15000
# train_accuracy :  0.892673
# validation_accuracy :  0.872
# Model saved in file: ./models/2016-12-09_3_3_model.ckpt
# epoch :  3
# i :  20000
# train_accuracy :  0.892164
# validation_accuracy :  0.8726
# Model saved in file: ./models/2016-12-09_3_4_model.ckpt
# epoch :  3
# i :  25000
# train_accuracy :  0.904491
# validation_accuracy :  0.8814
# Model saved in file: ./models/2016-12-09_3_5_model.ckpt
# epoch :  3
# i :  30000
# train_accuracy :  0.905928
# validation_accuracy :  0.8844
# Model saved in file: ./models/2016-12-09_3_6_model.ckpt
# epoch :  3
# i :  35000
# train_accuracy :  0.905564
# validation_accuracy :  0.8808
# Model saved in file: ./models/2016-12-09_3_7_model.ckpt
# epoch :  3
# i :  40000
# train_accuracy :  0.9054
# validation_accuracy :  0.8816
# Model saved in file: ./models/2016-12-09_3_8_model.ckpt
# epoch :  3
# i :  45000
# train_accuracy :  0.912364
# validation_accuracy :  0.8878
# Model saved in file: ./models/2016-12-09_3_9_model.ckpt
# epoch :  3
# i :  50000
# train_accuracy :  0.913255
# validation_accuracy :  0.8902
# Model saved in file: ./models/2016-12-09_3_10_model.ckpt
# epoch :  3
# i :  55000
# train_accuracy :  0.911346
# validation_accuracy :  0.8844
# Model saved in file: ./models/2016-12-09_3_11_model.ckpt
# One epoch finished
# epoch :  3
# train_accuracy :  0.911346
# validation_accuracy :  0.8844
# test_accuracy :  0.8898
# Model saved in file: ./models/2016-12-09_3_0_model.ckpt
# epoch :  4
# i :  5000
# train_accuracy :  0.9142
# validation_accuracy :  0.8882
# Model saved in file: ./models/2016-12-09_4_1_model.ckpt
# epoch :  4
# i :  10000
# train_accuracy :  0.9096
# validation_accuracy :  0.8834
# Model saved in file: ./models/2016-12-09_4_2_model.ckpt
# epoch :  4
# i :  15000
# train_accuracy :  0.916709
# validation_accuracy :  0.886
# Model saved in file: ./models/2016-12-09_4_3_model.ckpt
# epoch :  4
# i :  20000
# train_accuracy :  0.917764
# validation_accuracy :  0.8898
# Model saved in file: ./models/2016-12-09_4_4_model.ckpt
# epoch :  4
# i :  25000
# train_accuracy :  0.910455
# validation_accuracy :  0.8852
# Model saved in file: ./models/2016-12-09_4_5_model.ckpt
# epoch :  4
# i :  30000
# train_accuracy :  0.918019
# validation_accuracy :  0.8926
# Model saved in file: ./models/2016-12-09_4_6_model.ckpt
# epoch :  4
# i :  35000
# train_accuracy :  0.920764
# validation_accuracy :  0.8936
# Model saved in file: ./models/2016-12-09_4_7_model.ckpt
# epoch :  4
# i :  40000
# train_accuracy :  0.922728
# validation_accuracy :  0.8964
# Model saved in file: ./models/2016-12-09_4_8_model.ckpt
# epoch :  4
# i :  45000
# train_accuracy :  0.917837
# validation_accuracy :  0.8916
# Model saved in file: ./models/2016-12-09_4_9_model.ckpt
# epoch :  4
# i :  50000
# train_accuracy :  0.924982
# validation_accuracy :  0.899
# Model saved in file: ./models/2016-12-09_4_10_model.ckpt
# epoch :  4
# i :  55000
# train_accuracy :  0.923946
# validation_accuracy :  0.8954
# Model saved in file: ./models/2016-12-09_4_11_model.ckpt
# One epoch finished
# epoch :  4
# train_accuracy :  0.923946
# validation_accuracy :  0.8954
# test_accuracy :  0.9001
# Model saved in file: ./models/2016-12-09_4_0_model.ckpt
# epoch :  5
# i :  5000
# train_accuracy :  0.919491
# validation_accuracy :  0.8952
# Model saved in file: ./models/2016-12-09_5_1_model.ckpt
# epoch :  5
# i :  10000
# train_accuracy :  0.920182
# validation_accuracy :  0.8926
# Model saved in file: ./models/2016-12-09_5_2_model.ckpt
# epoch :  5
# i :  15000
# train_accuracy :  0.925982
# validation_accuracy :  0.898
# Model saved in file: ./models/2016-12-09_5_3_model.ckpt
# epoch :  5
# i :  20000
# train_accuracy :  0.922764
# validation_accuracy :  0.8946
# Model saved in file: ./models/2016-12-09_5_4_model.ckpt
# epoch :  5
# i :  25000
# train_accuracy :  0.926219
# validation_accuracy :  0.896
# Model saved in file: ./models/2016-12-09_5_5_model.ckpt
# epoch :  5
# i :  30000
# train_accuracy :  0.923091
# validation_accuracy :  0.8926
# Model saved in file: ./models/2016-12-09_5_6_model.ckpt
# epoch :  5
# i :  35000
# train_accuracy :  0.926509
# validation_accuracy :  0.8962
# Model saved in file: ./models/2016-12-09_5_7_model.ckpt
# epoch :  5
# i :  40000
# train_accuracy :  0.926982
# validation_accuracy :  0.8974
# Model saved in file: ./models/2016-12-09_5_8_model.ckpt
# epoch :  5
# i :  45000
# train_accuracy :  0.932255
# validation_accuracy :  0.9018
# Model saved in file: ./models/2016-12-09_5_9_model.ckpt
# epoch :  5
# i :  50000
# train_accuracy :  0.931237
# validation_accuracy :  0.902
# Model saved in file: ./models/2016-12-09_5_10_model.ckpt
# epoch :  5
# i :  55000
# train_accuracy :  0.930437
# validation_accuracy :  0.902
# Model saved in file: ./models/2016-12-09_5_11_model.ckpt
# One epoch finished
# epoch :  5
# train_accuracy :  0.930437
# validation_accuracy :  0.902
# test_accuracy :  0.9025
# Model saved in file: ./models/2016-12-09_5_0_model.ckpt
# epoch :  6
# i :  5000
# train_accuracy :  0.929928
# validation_accuracy :  0.9004
# Model saved in file: ./models/2016-12-09_6_1_model.ckpt
# epoch :  6
# i :  10000
# train_accuracy :  0.930146
# validation_accuracy :  0.8982
# Model saved in file: ./models/2016-12-09_6_2_model.ckpt
# epoch :  6
# i :  15000
# train_accuracy :  0.9246
# validation_accuracy :  0.897
# Model saved in file: ./models/2016-12-09_6_3_model.ckpt
# epoch :  6
# i :  20000
# train_accuracy :  0.930309
# validation_accuracy :  0.9022
# Model saved in file: ./models/2016-12-09_6_4_model.ckpt
# epoch :  6
# i :  25000
# train_accuracy :  0.929637
# validation_accuracy :  0.9014
# Model saved in file: ./models/2016-12-09_6_5_model.ckpt
# epoch :  6
# i :  30000
# train_accuracy :  0.926491
# validation_accuracy :  0.9012
# Model saved in file: ./models/2016-12-09_6_6_model.ckpt
# epoch :  6
# i :  35000
# train_accuracy :  0.934673
# validation_accuracy :  0.9082
# Model saved in file: ./models/2016-12-09_6_7_model.ckpt
# epoch :  6
# i :  40000
# train_accuracy :  0.935855
# validation_accuracy :  0.9108
# Model saved in file: ./models/2016-12-09_6_8_model.ckpt
# epoch :  6
# i :  45000
# train_accuracy :  0.935346
# validation_accuracy :  0.9102
# Model saved in file: ./models/2016-12-09_6_9_model.ckpt
# epoch :  6
# i :  50000
# train_accuracy :  0.936819
# validation_accuracy :  0.909
# Model saved in file: ./models/2016-12-09_6_10_model.ckpt
# epoch :  6
# i :  55000
# train_accuracy :  0.932218
# validation_accuracy :  0.9082
# Model saved in file: ./models/2016-12-09_6_11_model.ckpt
# One epoch finished
# epoch :  6
# train_accuracy :  0.932218
# validation_accuracy :  0.9082
# test_accuracy :  0.9011
# Model saved in file: ./models/2016-12-09_6_0_model.ckpt
# epoch :  7
# i :  5000
# train_accuracy :  0.933837
# validation_accuracy :  0.905
# Model saved in file: ./models/2016-12-09_7_1_model.ckpt
# epoch :  7
# i :  10000
# train_accuracy :  0.935128
# validation_accuracy :  0.9042
# Model saved in file: ./models/2016-12-09_7_2_model.ckpt
# epoch :  7
# i :  15000
# train_accuracy :  0.928673
# validation_accuracy :  0.902
# Model saved in file: ./models/2016-12-09_7_3_model.ckpt
# epoch :  7
# i :  20000
# train_accuracy :  0.93
# validation_accuracy :  0.905
# Model saved in file: ./models/2016-12-09_7_4_model.ckpt
# epoch :  7
# i :  25000
# train_accuracy :  0.938691
# validation_accuracy :  0.912
# Model saved in file: ./models/2016-12-09_7_5_model.ckpt
# epoch :  7
# i :  30000
# train_accuracy :  0.937509
# validation_accuracy :  0.91
# Model saved in file: ./models/2016-12-09_7_6_model.ckpt
# epoch :  7
# i :  35000
# train_accuracy :  0.933746
# validation_accuracy :  0.908
# Model saved in file: ./models/2016-12-09_7_7_model.ckpt
# epoch :  7
# i :  40000
# train_accuracy :  0.932546
# validation_accuracy :  0.9058
# Model saved in file: ./models/2016-12-09_7_8_model.ckpt
# epoch :  7
# i :  45000
# train_accuracy :  0.933037
# validation_accuracy :  0.907
# Model saved in file: ./models/2016-12-09_7_9_model.ckpt
# epoch :  7
# i :  50000
# train_accuracy :  0.942819
# validation_accuracy :  0.9164
# Model saved in file: ./models/2016-12-09_7_10_model.ckpt
# epoch :  7
# i :  55000
# train_accuracy :  0.941946
# validation_accuracy :  0.914
# Model saved in file: ./models/2016-12-09_7_11_model.ckpt
# One epoch finished
# epoch :  7
# train_accuracy :  0.941946
# validation_accuracy :  0.914
# test_accuracy :  0.9115
# Model saved in file: ./models/2016-12-09_7_0_model.ckpt
# epoch :  8
# i :  5000
# train_accuracy :  0.934637
# validation_accuracy :  0.9104
# Model saved in file: ./models/2016-12-09_8_1_model.ckpt
# epoch :  8
# i :  10000
# train_accuracy :  0.935509
# validation_accuracy :  0.91
# Model saved in file: ./models/2016-12-09_8_2_model.ckpt
# epoch :  8
# i :  15000
# train_accuracy :  0.936164
# validation_accuracy :  0.9096
# Model saved in file: ./models/2016-12-09_8_3_model.ckpt
# epoch :  8
# i :  20000
# train_accuracy :  0.942946
# validation_accuracy :  0.9124
# Model saved in file: ./models/2016-12-09_8_4_model.ckpt
# epoch :  8
# i :  25000
# train_accuracy :  0.931637
# validation_accuracy :  0.906
# Model saved in file: ./models/2016-12-09_8_5_model.ckpt
# epoch :  8
# i :  30000
# train_accuracy :  0.940346
# validation_accuracy :  0.917
# Model saved in file: ./models/2016-12-09_8_6_model.ckpt
# epoch :  8
# i :  35000
# train_accuracy :  0.943291
# validation_accuracy :  0.9198
# Model saved in file: ./models/2016-12-09_8_7_model.ckpt
# epoch :  8
# i :  40000
# train_accuracy :  0.942491
# validation_accuracy :  0.9168
# Model saved in file: ./models/2016-12-09_8_8_model.ckpt
# epoch :  8
# i :  45000
# train_accuracy :  0.940509
# validation_accuracy :  0.9162
# Model saved in file: ./models/2016-12-09_8_9_model.ckpt
# epoch :  8
# i :  50000
# train_accuracy :  0.93991
# validation_accuracy :  0.9158
# Model saved in file: ./models/2016-12-09_8_10_model.ckpt
# epoch :  8
# i :  55000
# train_accuracy :  0.9418
# validation_accuracy :  0.9134
# Model saved in file: ./models/2016-12-09_8_11_model.ckpt
# One epoch finished
# epoch :  8
# train_accuracy :  0.9418
# validation_accuracy :  0.9134
# test_accuracy :  0.9123
# Model saved in file: ./models/2016-12-09_8_0_model.ckpt
# epoch :  9
# i :  5000
# train_accuracy :  0.9354
# validation_accuracy :  0.911
# Model saved in file: ./models/2016-12-09_9_1_model.ckpt
# epoch :  9
# i :  10000
# train_accuracy :  0.939019
# validation_accuracy :  0.9086
# Model saved in file: ./models/2016-12-09_9_2_model.ckpt
# epoch :  9
# i :  15000
# train_accuracy :  0.940019
# validation_accuracy :  0.9094
# Model saved in file: ./models/2016-12-09_9_3_model.ckpt
# epoch :  9
# i :  20000
# train_accuracy :  0.937455
# validation_accuracy :  0.91
# Model saved in file: ./models/2016-12-09_9_4_model.ckpt
# epoch :  9
# i :  25000
# train_accuracy :  0.936364
# validation_accuracy :  0.9076
# Model saved in file: ./models/2016-12-09_9_5_model.ckpt
# epoch :  9
# i :  30000
# train_accuracy :  0.944673
# validation_accuracy :  0.9172
# Model saved in file: ./models/2016-12-09_9_6_model.ckpt
# epoch :  9
# i :  35000
# train_accuracy :  0.942473
# validation_accuracy :  0.9108
# Model saved in file: ./models/2016-12-09_9_7_model.ckpt
# epoch :  9
# i :  40000
# train_accuracy :  0.942491
# validation_accuracy :  0.9108
# Model saved in file: ./models/2016-12-09_9_8_model.ckpt
# epoch :  9
# i :  45000
# train_accuracy :  0.9412
# validation_accuracy :  0.9108
# Model saved in file: ./models/2016-12-09_9_9_model.ckpt
# epoch :  9
# i :  50000
# train_accuracy :  0.946309
# validation_accuracy :  0.9122
# Model saved in file: ./models/2016-12-09_9_10_model.ckpt
# epoch :  9
# i :  55000
# train_accuracy :  0.942982
# validation_accuracy :  0.9132
# Model saved in file: ./models/2016-12-09_9_11_model.ckpt
# One epoch finished
# epoch :  9
# train_accuracy :  0.942982
# validation_accuracy :  0.9132
# test_accuracy :  0.9122
# Model saved in file: ./models/2016-12-09_9_0_model.ckpt
# epoch :  10
# i :  5000
# train_accuracy :  0.940528
# validation_accuracy :  0.9106
# Model saved in file: ./models/2016-12-09_10_1_model.ckpt
# epoch :  10
# i :  10000
# train_accuracy :  0.939437
# validation_accuracy :  0.9076
# Model saved in file: ./models/2016-12-09_10_2_model.ckpt
# epoch :  10
# i :  15000
# train_accuracy :  0.942691
# validation_accuracy :  0.914
# Model saved in file: ./models/2016-12-09_10_3_model.ckpt
# epoch :  10
# i :  20000
# train_accuracy :  0.945619
# validation_accuracy :  0.9136
# Model saved in file: ./models/2016-12-09_10_4_model.ckpt
# epoch :  10
# i :  25000
# train_accuracy :  0.946764
# validation_accuracy :  0.9134
# Model saved in file: ./models/2016-12-09_10_5_model.ckpt
# epoch :  10
# i :  30000
# train_accuracy :  0.940691
# validation_accuracy :  0.9098
# Model saved in file: ./models/2016-12-09_10_6_model.ckpt
# epoch :  10
# i :  35000
# train_accuracy :  0.945
# validation_accuracy :  0.918
# Model saved in file: ./models/2016-12-09_10_7_model.ckpt
# epoch :  10
# i :  40000
# train_accuracy :  0.948237
# validation_accuracy :  0.918
# Model saved in file: ./models/2016-12-09_10_8_model.ckpt
# epoch :  10
# i :  45000
# train_accuracy :  0.942128
# validation_accuracy :  0.9134
# Model saved in file: ./models/2016-12-09_10_9_model.ckpt
# epoch :  10
# i :  50000
# train_accuracy :  0.941455
# validation_accuracy :  0.9086
# Model saved in file: ./models/2016-12-09_10_10_model.ckpt
# epoch :  10
# i :  55000
# train_accuracy :  0.9424
# validation_accuracy :  0.9178
# Model saved in file: ./models/2016-12-09_10_11_model.ckpt
# One epoch finished
# epoch :  10
# train_accuracy :  0.9424
# validation_accuracy :  0.9178
# test_accuracy :  0.9127
# Model saved in file: ./models/2016-12-09_10_0_model.ckpt
# epoch :  11
# i :  5000
# train_accuracy :  0.941491
# validation_accuracy :  0.914
# Model saved in file: ./models/2016-12-09_11_1_model.ckpt
# epoch :  11
# i :  10000
# train_accuracy :  0.944364
# validation_accuracy :  0.916
# Model saved in file: ./models/2016-12-09_11_2_model.ckpt
# epoch :  11
# i :  15000
# train_accuracy :  0.940782
# validation_accuracy :  0.915
# Model saved in file: ./models/2016-12-09_11_3_model.ckpt
# epoch :  11
# i :  20000
# train_accuracy :  0.949219
# validation_accuracy :  0.9188
# Model saved in file: ./models/2016-12-09_11_4_model.ckpt
# epoch :  11
# i :  25000
# train_accuracy :  0.941473
# validation_accuracy :  0.9142
# Model saved in file: ./models/2016-12-09_11_5_model.ckpt
# epoch :  11
# i :  30000
# train_accuracy :  0.947473
# validation_accuracy :  0.9182
# Model saved in file: ./models/2016-12-09_11_6_model.ckpt
# epoch :  11
# i :  35000
# train_accuracy :  0.945873
# validation_accuracy :  0.917
# Model saved in file: ./models/2016-12-09_11_7_model.ckpt
# epoch :  11
# i :  40000
# train_accuracy :  0.948309
# validation_accuracy :  0.9184
# Model saved in file: ./models/2016-12-09_11_8_model.ckpt
# epoch :  11
# i :  45000
# train_accuracy :  0.952473
# validation_accuracy :  0.9254
# Model saved in file: ./models/2016-12-09_11_9_model.ckpt
# epoch :  11
# i :  50000
# train_accuracy :  0.953328
# validation_accuracy :  0.9236
# Model saved in file: ./models/2016-12-09_11_10_model.ckpt
# epoch :  11
# i :  55000
# train_accuracy :  0.952182
# validation_accuracy :  0.9236
# Model saved in file: ./models/2016-12-09_11_11_model.ckpt
# One epoch finished
# epoch :  11
# train_accuracy :  0.952182
# validation_accuracy :  0.9236
# test_accuracy :  0.9206
# Model saved in file: ./models/2016-12-09_11_0_model.ckpt
# epoch :  12
# i :  5000
# train_accuracy :  0.9492
# validation_accuracy :  0.923
# Model saved in file: ./models/2016-12-09_12_1_model.ckpt
# epoch :  12
# i :  10000
# train_accuracy :  0.946964
# validation_accuracy :  0.9198
# Model saved in file: ./models/2016-12-09_12_2_model.ckpt
# epoch :  12
# i :  15000
# train_accuracy :  0.948637
# validation_accuracy :  0.9202
# Model saved in file: ./models/2016-12-09_12_3_model.ckpt
# epoch :  12
# i :  20000
# train_accuracy :  0.953764
# validation_accuracy :  0.922
# Model saved in file: ./models/2016-12-09_12_4_model.ckpt
# epoch :  12
# i :  25000
# train_accuracy :  0.950455
# validation_accuracy :  0.919
# Model saved in file: ./models/2016-12-09_12_5_model.ckpt
# epoch :  12
# i :  30000
# train_accuracy :  0.942146
# validation_accuracy :  0.9146
# Model saved in file: ./models/2016-12-09_12_6_model.ckpt
# epoch :  12
# i :  35000
# train_accuracy :  0.949182
# validation_accuracy :  0.92
# Model saved in file: ./models/2016-12-09_12_7_model.ckpt
# epoch :  12
# i :  40000
# train_accuracy :  0.946546
# validation_accuracy :  0.9162
# Model saved in file: ./models/2016-12-09_12_8_model.ckpt
# epoch :  12
# i :  45000
# train_accuracy :  0.947855
# validation_accuracy :  0.919
# Model saved in file: ./models/2016-12-09_12_9_model.ckpt
# epoch :  12
# i :  50000
# train_accuracy :  0.945564
# validation_accuracy :  0.917
# Model saved in file: ./models/2016-12-09_12_10_model.ckpt
# epoch :  12
# i :  55000
# train_accuracy :  0.9518
# validation_accuracy :  0.9252
# Model saved in file: ./models/2016-12-09_12_11_model.ckpt
# One epoch finished
# epoch :  12
# train_accuracy :  0.9518
# validation_accuracy :  0.9252
# test_accuracy :  0.9224
# Model saved in file: ./models/2016-12-09_12_0_model.ckpt
# epoch :  13
# i :  5000
# train_accuracy :  0.939346
# validation_accuracy :  0.9142
# Model saved in file: ./models/2016-12-09_13_1_model.ckpt
# epoch :  13
# i :  10000
# train_accuracy :  0.946455
# validation_accuracy :  0.9162
# Model saved in file: ./models/2016-12-09_13_2_model.ckpt
# epoch :  13
# i :  15000
# train_accuracy :  0.953164
# validation_accuracy :  0.924
# Model saved in file: ./models/2016-12-09_13_3_model.ckpt
# epoch :  13
# i :  20000
# train_accuracy :  0.950437
# validation_accuracy :  0.9226
# Model saved in file: ./models/2016-12-09_13_4_model.ckpt
# epoch :  13
# i :  25000
# train_accuracy :  0.949873
# validation_accuracy :  0.92
# Model saved in file: ./models/2016-12-09_13_5_model.ckpt
# epoch :  13
# i :  30000
# train_accuracy :  0.951419
# validation_accuracy :  0.9222
# Model saved in file: ./models/2016-12-09_13_6_model.ckpt
# epoch :  13
# i :  35000
# train_accuracy :  0.949091
# validation_accuracy :  0.92
# Model saved in file: ./models/2016-12-09_13_7_model.ckpt
# epoch :  13
# i :  40000
# train_accuracy :  0.949219
# validation_accuracy :  0.9198
# Model saved in file: ./models/2016-12-09_13_8_model.ckpt
# epoch :  13
# i :  45000
# train_accuracy :  0.955109
# validation_accuracy :  0.9234
# Model saved in file: ./models/2016-12-09_13_9_model.ckpt
# epoch :  13
# i :  50000
# train_accuracy :  0.948491
# validation_accuracy :  0.9208
# Model saved in file: ./models/2016-12-09_13_10_model.ckpt
# epoch :  13
# i :  55000
# train_accuracy :  0.956419
# validation_accuracy :  0.927
# Model saved in file: ./models/2016-12-09_13_11_model.ckpt
# One epoch finished
# epoch :  13
# train_accuracy :  0.956419
# validation_accuracy :  0.927
# test_accuracy :  0.9232
# Model saved in file: ./models/2016-12-09_13_0_model.ckpt
# epoch :  14
# i :  5000
# train_accuracy :  0.951164
# validation_accuracy :  0.9224
# Model saved in file: ./models/2016-12-09_14_1_model.ckpt
# epoch :  14
# i :  10000
# train_accuracy :  0.946546
# validation_accuracy :  0.9194
# Model saved in file: ./models/2016-12-09_14_2_model.ckpt
# epoch :  14
# i :  15000
# train_accuracy :  0.951382
# validation_accuracy :  0.9222
# Model saved in file: ./models/2016-12-09_14_3_model.ckpt
# epoch :  14
# i :  20000
# train_accuracy :  0.950128
# validation_accuracy :  0.9228
# Model saved in file: ./models/2016-12-09_14_4_model.ckpt
# epoch :  14
# i :  25000
# train_accuracy :  0.943509
# validation_accuracy :  0.9188
# Model saved in file: ./models/2016-12-09_14_5_model.ckpt
# epoch :  14
# i :  30000
# train_accuracy :  0.952418
# validation_accuracy :  0.9254
# Model saved in file: ./models/2016-12-09_14_6_model.ckpt
# epoch :  14
# i :  35000
# train_accuracy :  0.949873
# validation_accuracy :  0.9242
# Model saved in file: ./models/2016-12-09_14_7_model.ckpt
# epoch :  14
# i :  40000
# train_accuracy :  0.947219
# validation_accuracy :  0.9216
# Model saved in file: ./models/2016-12-09_14_8_model.ckpt
# epoch :  14
# i :  45000
# train_accuracy :  0.953782
# validation_accuracy :  0.9266
# Model saved in file: ./models/2016-12-09_14_9_model.ckpt
# epoch :  14
# i :  50000
# train_accuracy :  0.954982
# validation_accuracy :  0.9276
# Model saved in file: ./models/2016-12-09_14_10_model.ckpt
# epoch :  14
# i :  55000
# train_accuracy :  0.950928
# validation_accuracy :  0.925
# Model saved in file: ./models/2016-12-09_14_11_model.ckpt
# One epoch finished
# epoch :  14
# train_accuracy :  0.950928
# validation_accuracy :  0.925
# test_accuracy :  0.919
# Model saved in file: ./models/2016-12-09_14_0_model.ckpt
# epoch :  15
# i :  5000
# train_accuracy :  0.950328
# validation_accuracy :  0.9246
# Model saved in file: ./models/2016-12-09_15_1_model.ckpt
# epoch :  15
# i :  10000
# train_accuracy :  0.947655
# validation_accuracy :  0.9212
# Model saved in file: ./models/2016-12-09_15_2_model.ckpt
# epoch :  15
# i :  15000
# train_accuracy :  0.952146
# validation_accuracy :  0.9262
# Model saved in file: ./models/2016-12-09_15_3_model.ckpt
# epoch :  15
# i :  20000
# train_accuracy :  0.952146
# validation_accuracy :  0.9232
# Model saved in file: ./models/2016-12-09_15_4_model.ckpt
# epoch :  15
# i :  25000
# train_accuracy :  0.957473
# validation_accuracy :  0.928
# Model saved in file: ./models/2016-12-09_15_5_model.ckpt
# epoch :  15
# i :  30000
# train_accuracy :  0.9576
# validation_accuracy :  0.9288
# Model saved in file: ./models/2016-12-09_15_6_model.ckpt
# epoch :  15
# i :  35000
# train_accuracy :  0.947309
# validation_accuracy :  0.921
# Model saved in file: ./models/2016-12-09_15_7_model.ckpt
# epoch :  15
# i :  40000
# train_accuracy :  0.950891
# validation_accuracy :  0.9218
# Model saved in file: ./models/2016-12-09_15_8_model.ckpt
# epoch :  15
# i :  45000
# train_accuracy :  0.949691
# validation_accuracy :  0.9244
# Model saved in file: ./models/2016-12-09_15_9_model.ckpt
# epoch :  15
# i :  50000
# train_accuracy :  0.957964
# validation_accuracy :  0.9298
# Model saved in file: ./models/2016-12-09_15_10_model.ckpt
# epoch :  15
# i :  55000
# train_accuracy :  0.958582
# validation_accuracy :  0.9282
# Model saved in file: ./models/2016-12-09_15_11_model.ckpt
# One epoch finished
# epoch :  15
# train_accuracy :  0.958582
# validation_accuracy :  0.9282
# test_accuracy :  0.9248
# Model saved in file: ./models/2016-12-09_15_0_model.ckpt
# epoch :  16
# i :  5000
# train_accuracy :  0.958309
# validation_accuracy :  0.9258
# Model saved in file: ./models/2016-12-09_16_1_model.ckpt
# epoch :  16
# i :  10000
# train_accuracy :  0.949873
# validation_accuracy :  0.921
# Model saved in file: ./models/2016-12-09_16_2_model.ckpt
# epoch :  16
# i :  15000
# train_accuracy :  0.948473
# validation_accuracy :  0.9204
# Model saved in file: ./models/2016-12-09_16_3_model.ckpt
# epoch :  16
# i :  20000
# train_accuracy :  0.956782
# validation_accuracy :  0.9278
# Model saved in file: ./models/2016-12-09_16_4_model.ckpt
# epoch :  16
# i :  25000
# train_accuracy :  0.956255
# validation_accuracy :  0.927
# Model saved in file: ./models/2016-12-09_16_5_model.ckpt
# epoch :  16
# i :  30000
# train_accuracy :  0.951837
# validation_accuracy :  0.9274
# Model saved in file: ./models/2016-12-09_16_6_model.ckpt
# epoch :  16
# i :  35000
# train_accuracy :  0.949909
# validation_accuracy :  0.9238
# Model saved in file: ./models/2016-12-09_16_7_model.ckpt
# epoch :  16
# i :  40000
# train_accuracy :  0.957146
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_16_8_model.ckpt
# epoch :  16
# i :  45000
# train_accuracy :  0.950891
# validation_accuracy :  0.9244
# Model saved in file: ./models/2016-12-09_16_9_model.ckpt
# epoch :  16
# i :  50000
# train_accuracy :  0.957018
# validation_accuracy :  0.9304
# Model saved in file: ./models/2016-12-09_16_10_model.ckpt
# epoch :  16
# i :  55000
# train_accuracy :  0.960618
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_16_11_model.ckpt
# One epoch finished
# epoch :  16
# train_accuracy :  0.960618
# validation_accuracy :  0.9312
# test_accuracy :  0.9273
# Model saved in file: ./models/2016-12-09_16_0_model.ckpt
# epoch :  17
# i :  5000
# train_accuracy :  0.951619
# validation_accuracy :  0.9264
# Model saved in file: ./models/2016-12-09_17_1_model.ckpt
# epoch :  17
# i :  10000
# train_accuracy :  0.956437
# validation_accuracy :  0.9272
# Model saved in file: ./models/2016-12-09_17_2_model.ckpt
# epoch :  17
# i :  15000
# train_accuracy :  0.953164
# validation_accuracy :  0.9246
# Model saved in file: ./models/2016-12-09_17_3_model.ckpt
# epoch :  17
# i :  20000
# train_accuracy :  0.955364
# validation_accuracy :  0.926
# Model saved in file: ./models/2016-12-09_17_4_model.ckpt
# epoch :  17
# i :  25000
# train_accuracy :  0.957564
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_17_5_model.ckpt
# epoch :  17
# i :  30000
# train_accuracy :  0.958782
# validation_accuracy :  0.9292
# Model saved in file: ./models/2016-12-09_17_6_model.ckpt
# epoch :  17
# i :  35000
# train_accuracy :  0.959309
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_17_7_model.ckpt
# epoch :  17
# i :  40000
# train_accuracy :  0.955855
# validation_accuracy :  0.927
# Model saved in file: ./models/2016-12-09_17_8_model.ckpt
# epoch :  17
# i :  45000
# train_accuracy :  0.961728
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_17_9_model.ckpt
# epoch :  17
# i :  50000
# train_accuracy :  0.953637
# validation_accuracy :  0.9274
# Model saved in file: ./models/2016-12-09_17_10_model.ckpt
# epoch :  17
# i :  55000
# train_accuracy :  0.953091
# validation_accuracy :  0.9248
# Model saved in file: ./models/2016-12-09_17_11_model.ckpt
# One epoch finished
# epoch :  17
# train_accuracy :  0.953091
# validation_accuracy :  0.9248
# test_accuracy :  0.9206
# Model saved in file: ./models/2016-12-09_17_0_model.ckpt
# epoch :  18
# i :  5000
# train_accuracy :  0.955873
# validation_accuracy :  0.9282
# Model saved in file: ./models/2016-12-09_18_1_model.ckpt
# epoch :  18
# i :  10000
# train_accuracy :  0.958728
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_18_2_model.ckpt
# epoch :  18
# i :  15000
# train_accuracy :  0.955946
# validation_accuracy :  0.9276
# Model saved in file: ./models/2016-12-09_18_3_model.ckpt
# epoch :  18
# i :  20000
# train_accuracy :  0.957073
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_18_4_model.ckpt
# epoch :  18
# i :  25000
# train_accuracy :  0.960455
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_18_5_model.ckpt
# epoch :  18
# i :  30000
# train_accuracy :  0.960273
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_18_6_model.ckpt
# epoch :  18
# i :  35000
# train_accuracy :  0.957073
# validation_accuracy :  0.9256
# Model saved in file: ./models/2016-12-09_18_7_model.ckpt
# epoch :  18
# i :  40000
# train_accuracy :  0.958273
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_18_8_model.ckpt
# epoch :  18
# i :  45000
# train_accuracy :  0.955364
# validation_accuracy :  0.9254
# Model saved in file: ./models/2016-12-09_18_9_model.ckpt
# epoch :  18
# i :  50000
# train_accuracy :  0.962655
# validation_accuracy :  0.929
# Model saved in file: ./models/2016-12-09_18_10_model.ckpt
# epoch :  18
# i :  55000
# train_accuracy :  0.955873
# validation_accuracy :  0.9238
# Model saved in file: ./models/2016-12-09_18_11_model.ckpt
# One epoch finished
# epoch :  18
# train_accuracy :  0.955873
# validation_accuracy :  0.9238
# test_accuracy :  0.9223
# Model saved in file: ./models/2016-12-09_18_0_model.ckpt
# epoch :  19
# i :  5000
# train_accuracy :  0.961582
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_19_1_model.ckpt
# epoch :  19
# i :  10000
# train_accuracy :  0.962128
# validation_accuracy :  0.9318
# Model saved in file: ./models/2016-12-09_19_2_model.ckpt
# epoch :  19
# i :  15000
# train_accuracy :  0.960928
# validation_accuracy :  0.9276
# Model saved in file: ./models/2016-12-09_19_3_model.ckpt
# epoch :  19
# i :  20000
# train_accuracy :  0.959473
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_19_4_model.ckpt
# epoch :  19
# i :  25000
# train_accuracy :  0.959928
# validation_accuracy :  0.9286
# Model saved in file: ./models/2016-12-09_19_5_model.ckpt
# epoch :  19
# i :  30000
# train_accuracy :  0.963237
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_19_6_model.ckpt
# epoch :  19
# i :  35000
# train_accuracy :  0.961691
# validation_accuracy :  0.9296
# Model saved in file: ./models/2016-12-09_19_7_model.ckpt
# epoch :  19
# i :  40000
# train_accuracy :  0.956091
# validation_accuracy :  0.925
# Model saved in file: ./models/2016-12-09_19_8_model.ckpt
# epoch :  19
# i :  45000
# train_accuracy :  0.962982
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_19_9_model.ckpt
# epoch :  19
# i :  50000
# train_accuracy :  0.963455
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_19_10_model.ckpt
# epoch :  19
# i :  55000
# train_accuracy :  0.963346
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_19_11_model.ckpt
# One epoch finished
# epoch :  19
# train_accuracy :  0.963346
# validation_accuracy :  0.9324
# test_accuracy :  0.9305
# Model saved in file: ./models/2016-12-09_19_0_model.ckpt
# epoch :  20
# i :  5000
# train_accuracy :  0.961928
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_20_1_model.ckpt
# epoch :  20
# i :  10000
# train_accuracy :  0.960491
# validation_accuracy :  0.9286
# Model saved in file: ./models/2016-12-09_20_2_model.ckpt
# epoch :  20
# i :  15000
# train_accuracy :  0.96351
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_20_3_model.ckpt
# epoch :  20
# i :  20000
# train_accuracy :  0.956818
# validation_accuracy :  0.9274
# Model saved in file: ./models/2016-12-09_20_4_model.ckpt
# epoch :  20
# i :  25000
# train_accuracy :  0.959346
# validation_accuracy :  0.9296
# Model saved in file: ./models/2016-12-09_20_5_model.ckpt
# epoch :  20
# i :  30000
# train_accuracy :  0.9592
# validation_accuracy :  0.928
# Model saved in file: ./models/2016-12-09_20_6_model.ckpt
# epoch :  20
# i :  35000
# train_accuracy :  0.965909
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_20_7_model.ckpt
# epoch :  20
# i :  40000
# train_accuracy :  0.963018
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_20_8_model.ckpt
# epoch :  20
# i :  45000
# train_accuracy :  0.962673
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_20_9_model.ckpt
# epoch :  20
# i :  50000
# train_accuracy :  0.963218
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_20_10_model.ckpt
# epoch :  20
# i :  55000
# train_accuracy :  0.962346
# validation_accuracy :  0.9292
# Model saved in file: ./models/2016-12-09_20_11_model.ckpt
# One epoch finished
# epoch :  20
# train_accuracy :  0.962346
# validation_accuracy :  0.9292
# test_accuracy :  0.9264
# Model saved in file: ./models/2016-12-09_20_0_model.ckpt
# epoch :  21
# i :  5000
# train_accuracy :  0.962982
# validation_accuracy :  0.9308
# Model saved in file: ./models/2016-12-09_21_1_model.ckpt
# epoch :  21
# i :  10000
# train_accuracy :  0.963691
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_21_2_model.ckpt
# epoch :  21
# i :  15000
# train_accuracy :  0.960509
# validation_accuracy :  0.931
# Model saved in file: ./models/2016-12-09_21_3_model.ckpt
# epoch :  21
# i :  20000
# train_accuracy :  0.964655
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_21_4_model.ckpt
# epoch :  21
# i :  25000
# train_accuracy :  0.962564
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_21_5_model.ckpt
# epoch :  21
# i :  30000
# train_accuracy :  0.956909
# validation_accuracy :  0.926
# Model saved in file: ./models/2016-12-09_21_6_model.ckpt
# epoch :  21
# i :  35000
# train_accuracy :  0.959437
# validation_accuracy :  0.9286
# Model saved in file: ./models/2016-12-09_21_7_model.ckpt
# epoch :  21
# i :  40000
# train_accuracy :  0.9638
# validation_accuracy :  0.9338
# Model saved in file: ./models/2016-12-09_21_8_model.ckpt
# epoch :  21
# i :  45000
# train_accuracy :  0.965019
# validation_accuracy :  0.9348
# Model saved in file: ./models/2016-12-09_21_9_model.ckpt
# epoch :  21
# i :  50000
# train_accuracy :  0.963491
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_21_10_model.ckpt
# epoch :  21
# i :  55000
# train_accuracy :  0.964909
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_21_11_model.ckpt
# One epoch finished
# epoch :  21
# train_accuracy :  0.964909
# validation_accuracy :  0.9322
# test_accuracy :  0.9287
# Model saved in file: ./models/2016-12-09_21_0_model.ckpt
# epoch :  22
# i :  5000
# train_accuracy :  0.961055
# validation_accuracy :  0.9282
# Model saved in file: ./models/2016-12-09_22_1_model.ckpt
# epoch :  22
# i :  10000
# train_accuracy :  0.965182
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_22_2_model.ckpt
# epoch :  22
# i :  15000
# train_accuracy :  0.9598
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_22_3_model.ckpt
# epoch :  22
# i :  20000
# train_accuracy :  0.963128
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_22_4_model.ckpt
# epoch :  22
# i :  25000
# train_accuracy :  0.962528
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_22_5_model.ckpt
# epoch :  22
# i :  30000
# train_accuracy :  0.964746
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_22_6_model.ckpt
# epoch :  22
# i :  35000
# train_accuracy :  0.959291
# validation_accuracy :  0.9284
# Model saved in file: ./models/2016-12-09_22_7_model.ckpt
# epoch :  22
# i :  40000
# train_accuracy :  0.963819
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_22_8_model.ckpt
# epoch :  22
# i :  45000
# train_accuracy :  0.965964
# validation_accuracy :  0.9304
# Model saved in file: ./models/2016-12-09_22_9_model.ckpt
# epoch :  22
# i :  50000
# train_accuracy :  0.965964
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_22_10_model.ckpt
# epoch :  22
# i :  55000
# train_accuracy :  0.961728
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_22_11_model.ckpt
# One epoch finished
# epoch :  22
# train_accuracy :  0.961728
# validation_accuracy :  0.9336
# test_accuracy :  0.9258
# Model saved in file: ./models/2016-12-09_22_0_model.ckpt
# epoch :  23
# i :  5000
# train_accuracy :  0.961819
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_23_1_model.ckpt
# epoch :  23
# i :  10000
# train_accuracy :  0.963328
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_23_2_model.ckpt
# epoch :  23
# i :  15000
# train_accuracy :  0.966491
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_23_3_model.ckpt
# epoch :  23
# i :  20000
# train_accuracy :  0.964382
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_23_4_model.ckpt
# epoch :  23
# i :  25000
# train_accuracy :  0.966546
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_23_5_model.ckpt
# epoch :  23
# i :  30000
# train_accuracy :  0.961909
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_23_6_model.ckpt
# epoch :  23
# i :  35000
# train_accuracy :  0.966055
# validation_accuracy :  0.9362
# Model saved in file: ./models/2016-12-09_23_7_model.ckpt
# epoch :  23
# i :  40000
# train_accuracy :  0.959146
# validation_accuracy :  0.931
# Model saved in file: ./models/2016-12-09_23_8_model.ckpt
# epoch :  23
# i :  45000
# train_accuracy :  0.9652
# validation_accuracy :  0.9332
# Model saved in file: ./models/2016-12-09_23_9_model.ckpt
# epoch :  23
# i :  50000
# train_accuracy :  0.968455
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_23_10_model.ckpt
# epoch :  23
# i :  55000
# train_accuracy :  0.967219
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_23_11_model.ckpt
# One epoch finished
# epoch :  23
# train_accuracy :  0.967219
# validation_accuracy :  0.9324
# test_accuracy :  0.9307
# Model saved in file: ./models/2016-12-09_23_0_model.ckpt
# epoch :  24
# i :  5000
# train_accuracy :  0.967528
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_24_1_model.ckpt
# epoch :  24
# i :  10000
# train_accuracy :  0.961655
# validation_accuracy :  0.9286
# Model saved in file: ./models/2016-12-09_24_2_model.ckpt
# epoch :  24
# i :  15000
# train_accuracy :  0.961764
# validation_accuracy :  0.9284
# Model saved in file: ./models/2016-12-09_24_3_model.ckpt
# epoch :  24
# i :  20000
# train_accuracy :  0.963018
# validation_accuracy :  0.9304
# Model saved in file: ./models/2016-12-09_24_4_model.ckpt
# epoch :  24
# i :  25000
# train_accuracy :  0.963782
# validation_accuracy :  0.9296
# Model saved in file: ./models/2016-12-09_24_5_model.ckpt
# epoch :  24
# i :  30000
# train_accuracy :  0.966637
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_24_6_model.ckpt
# epoch :  24
# i :  35000
# train_accuracy :  0.966728
# validation_accuracy :  0.9284
# Model saved in file: ./models/2016-12-09_24_7_model.ckpt
# epoch :  24
# i :  40000
# train_accuracy :  0.968873
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_24_8_model.ckpt
# epoch :  24
# i :  45000
# train_accuracy :  0.964818
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_24_9_model.ckpt
# epoch :  24
# i :  50000
# train_accuracy :  0.9688
# validation_accuracy :  0.9348
# Model saved in file: ./models/2016-12-09_24_10_model.ckpt
# epoch :  24
# i :  55000
# train_accuracy :  0.960491
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_24_11_model.ckpt
# One epoch finished
# epoch :  24
# train_accuracy :  0.960491
# validation_accuracy :  0.9328
# test_accuracy :  0.9258
# Model saved in file: ./models/2016-12-09_24_0_model.ckpt
# epoch :  25
# i :  5000
# train_accuracy :  0.968455
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_25_1_model.ckpt
# epoch :  25
# i :  10000
# train_accuracy :  0.964582
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_25_2_model.ckpt
# epoch :  25
# i :  15000
# train_accuracy :  0.965818
# validation_accuracy :  0.9306
# Model saved in file: ./models/2016-12-09_25_3_model.ckpt
# epoch :  25
# i :  20000
# train_accuracy :  0.963
# validation_accuracy :  0.9292
# Model saved in file: ./models/2016-12-09_25_4_model.ckpt
# epoch :  25
# i :  25000
# train_accuracy :  0.966837
# validation_accuracy :  0.9298
# Model saved in file: ./models/2016-12-09_25_5_model.ckpt
# epoch :  25
# i :  30000
# train_accuracy :  0.966255
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_25_6_model.ckpt
# epoch :  25
# i :  35000
# train_accuracy :  0.968873
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_25_7_model.ckpt
# epoch :  25
# i :  40000
# train_accuracy :  0.968964
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_25_8_model.ckpt
# epoch :  25
# i :  45000
# train_accuracy :  0.965637
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_25_9_model.ckpt
# epoch :  25
# i :  50000
# train_accuracy :  0.966273
# validation_accuracy :  0.9332
# Model saved in file: ./models/2016-12-09_25_10_model.ckpt
# epoch :  25
# i :  55000
# train_accuracy :  0.968346
# validation_accuracy :  0.9356
# Model saved in file: ./models/2016-12-09_25_11_model.ckpt
# One epoch finished
# epoch :  25
# train_accuracy :  0.968346
# validation_accuracy :  0.9356
# test_accuracy :  0.9317
# Model saved in file: ./models/2016-12-09_25_0_model.ckpt
# epoch :  26
# i :  5000
# train_accuracy :  0.969837
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_26_1_model.ckpt
# epoch :  26
# i :  10000
# train_accuracy :  0.958546
# validation_accuracy :  0.9256
# Model saved in file: ./models/2016-12-09_26_2_model.ckpt
# epoch :  26
# i :  15000
# train_accuracy :  0.970382
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_26_3_model.ckpt
# epoch :  26
# i :  20000
# train_accuracy :  0.968746
# validation_accuracy :  0.931
# Model saved in file: ./models/2016-12-09_26_4_model.ckpt
# epoch :  26
# i :  25000
# train_accuracy :  0.967309
# validation_accuracy :  0.9296
# Model saved in file: ./models/2016-12-09_26_5_model.ckpt
# epoch :  26
# i :  30000
# train_accuracy :  0.963164
# validation_accuracy :  0.9288
# Model saved in file: ./models/2016-12-09_26_6_model.ckpt
# epoch :  26
# i :  35000
# train_accuracy :  0.969073
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_26_7_model.ckpt
# epoch :  26
# i :  40000
# train_accuracy :  0.969546
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_26_8_model.ckpt
# epoch :  26
# i :  45000
# train_accuracy :  0.967837
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_26_9_model.ckpt
# epoch :  26
# i :  50000
# train_accuracy :  0.969382
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_26_10_model.ckpt
# epoch :  26
# i :  55000
# train_accuracy :  0.969855
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_26_11_model.ckpt
# One epoch finished
# epoch :  26
# train_accuracy :  0.969855
# validation_accuracy :  0.9346
# test_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_26_0_model.ckpt
# epoch :  27
# i :  5000
# train_accuracy :  0.972655
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_27_1_model.ckpt
# epoch :  27
# i :  10000
# train_accuracy :  0.968728
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_27_2_model.ckpt
# epoch :  27
# i :  15000
# train_accuracy :  0.967673
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_27_3_model.ckpt
# epoch :  27
# i :  20000
# train_accuracy :  0.968127
# validation_accuracy :  0.9296
# Model saved in file: ./models/2016-12-09_27_4_model.ckpt
# epoch :  27
# i :  25000
# train_accuracy :  0.970346
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_27_5_model.ckpt
# epoch :  27
# i :  30000
# train_accuracy :  0.966291
# validation_accuracy :  0.929
# Model saved in file: ./models/2016-12-09_27_6_model.ckpt
# epoch :  27
# i :  35000
# train_accuracy :  0.967655
# validation_accuracy :  0.931
# Model saved in file: ./models/2016-12-09_27_7_model.ckpt
# epoch :  27
# i :  40000
# train_accuracy :  0.964491
# validation_accuracy :  0.928
# Model saved in file: ./models/2016-12-09_27_8_model.ckpt
# epoch :  27
# i :  45000
# train_accuracy :  0.964509
# validation_accuracy :  0.9264
# Model saved in file: ./models/2016-12-09_27_9_model.ckpt
# epoch :  27
# i :  50000
# train_accuracy :  0.970382
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_27_10_model.ckpt
# epoch :  27
# i :  55000
# train_accuracy :  0.974819
# validation_accuracy :  0.9356
# Model saved in file: ./models/2016-12-09_27_11_model.ckpt
# One epoch finished
# epoch :  27
# train_accuracy :  0.974819
# validation_accuracy :  0.9356
# test_accuracy :  0.935
# Model saved in file: ./models/2016-12-09_27_0_model.ckpt
# epoch :  28
# i :  5000
# train_accuracy :  0.970564
# validation_accuracy :  0.9292
# Model saved in file: ./models/2016-12-09_28_1_model.ckpt
# epoch :  28
# i :  10000
# train_accuracy :  0.967073
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_28_2_model.ckpt
# epoch :  28
# i :  15000
# train_accuracy :  0.968146
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_28_3_model.ckpt
# epoch :  28
# i :  20000
# train_accuracy :  0.966637
# validation_accuracy :  0.9306
# Model saved in file: ./models/2016-12-09_28_4_model.ckpt
# epoch :  28
# i :  25000
# train_accuracy :  0.968818
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_28_5_model.ckpt
# epoch :  28
# i :  30000
# train_accuracy :  0.963073
# validation_accuracy :  0.9264
# Model saved in file: ./models/2016-12-09_28_6_model.ckpt
# epoch :  28
# i :  35000
# train_accuracy :  0.968146
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_28_7_model.ckpt
# epoch :  28
# i :  40000
# train_accuracy :  0.950073
# validation_accuracy :  0.9202
# Model saved in file: ./models/2016-12-09_28_8_model.ckpt
# epoch :  28
# i :  45000
# train_accuracy :  0.970582
# validation_accuracy :  0.9298
# Model saved in file: ./models/2016-12-09_28_9_model.ckpt
# epoch :  28
# i :  50000
# train_accuracy :  0.966982
# validation_accuracy :  0.9308
# Model saved in file: ./models/2016-12-09_28_10_model.ckpt
# epoch :  28
# i :  55000
# train_accuracy :  0.970455
# validation_accuracy :  0.93
# Model saved in file: ./models/2016-12-09_28_11_model.ckpt
# One epoch finished
# epoch :  28
# train_accuracy :  0.970455
# validation_accuracy :  0.93
# test_accuracy :  0.9321
# Model saved in file: ./models/2016-12-09_28_0_model.ckpt
# epoch :  29
# i :  5000
# train_accuracy :  0.968509
# validation_accuracy :  0.927
# Model saved in file: ./models/2016-12-09_29_1_model.ckpt
# epoch :  29
# i :  10000
# train_accuracy :  0.970928
# validation_accuracy :  0.929
# Model saved in file: ./models/2016-12-09_29_2_model.ckpt
# epoch :  29
# i :  15000
# train_accuracy :  0.971546
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_29_3_model.ckpt
# epoch :  29
# i :  20000
# train_accuracy :  0.970364
# validation_accuracy :  0.9308
# Model saved in file: ./models/2016-12-09_29_4_model.ckpt
# epoch :  29
# i :  25000
# train_accuracy :  0.9666
# validation_accuracy :  0.9274
# Model saved in file: ./models/2016-12-09_29_5_model.ckpt
# epoch :  29
# i :  30000
# train_accuracy :  0.969473
# validation_accuracy :  0.9288
# Model saved in file: ./models/2016-12-09_29_6_model.ckpt
# epoch :  29
# i :  35000
# train_accuracy :  0.965564
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_29_7_model.ckpt
# epoch :  29
# i :  40000
# train_accuracy :  0.958837
# validation_accuracy :  0.923
# Model saved in file: ./models/2016-12-09_29_8_model.ckpt
# epoch :  29
# i :  45000
# train_accuracy :  0.970655
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_29_9_model.ckpt
# epoch :  29
# i :  50000
# train_accuracy :  0.969055
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_29_10_model.ckpt
# epoch :  29
# i :  55000
# ...
# Model saved in file: ./models/2016-12-09_75_10_model.ckpt
# epoch :  75
# i :  55000
# train_accuracy :  0.972309
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_75_11_model.ckpt
# One epoch finished
# epoch :  75
# train_accuracy :  0.972309
# validation_accuracy :  0.9328
# test_accuracy :  0.9288
# Model saved in file: ./models/2016-12-09_75_0_model.ckpt
# epoch :  76
# i :  5000
# train_accuracy :  0.977982
# validation_accuracy :  0.9348
# Model saved in file: ./models/2016-12-09_76_1_model.ckpt
# epoch :  76
# i :  10000
# train_accuracy :  0.972637
# validation_accuracy :  0.9358
# Model saved in file: ./models/2016-12-09_76_2_model.ckpt
# epoch :  76
# i :  15000
# train_accuracy :  0.977055
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_76_3_model.ckpt
# epoch :  76
# i :  20000
# train_accuracy :  0.975455
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_76_4_model.ckpt
# epoch :  76
# i :  25000
# train_accuracy :  0.967637
# validation_accuracy :  0.9298
# Model saved in file: ./models/2016-12-09_76_5_model.ckpt
# epoch :  76
# i :  30000
# train_accuracy :  0.976473
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_76_6_model.ckpt
# epoch :  76
# i :  35000
# train_accuracy :  0.971655
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_76_7_model.ckpt
# epoch :  76
# i :  40000
# train_accuracy :  0.977509
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_76_8_model.ckpt
# epoch :  76
# i :  45000
# train_accuracy :  0.976673
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_76_9_model.ckpt
# epoch :  76
# i :  50000
# train_accuracy :  0.975473
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_76_10_model.ckpt
# epoch :  76
# i :  55000
# train_accuracy :  0.978837
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_76_11_model.ckpt
# One epoch finished
# epoch :  76
# train_accuracy :  0.978837
# validation_accuracy :  0.9354
# test_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_76_0_model.ckpt
# epoch :  77
# i :  5000
# train_accuracy :  0.972855
# validation_accuracy :  0.9318
# Model saved in file: ./models/2016-12-09_77_1_model.ckpt
# epoch :  77
# i :  10000
# train_accuracy :  0.976018
# validation_accuracy :  0.9332
# Model saved in file: ./models/2016-12-09_77_2_model.ckpt
# epoch :  77
# i :  15000
# train_accuracy :  0.975928
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_77_3_model.ckpt
# epoch :  77
# i :  20000
# train_accuracy :  0.9684
# validation_accuracy :  0.9304
# Model saved in file: ./models/2016-12-09_77_4_model.ckpt
# epoch :  77
# i :  25000
# train_accuracy :  0.978437
# validation_accuracy :  0.9366
# Model saved in file: ./models/2016-12-09_77_5_model.ckpt
# epoch :  77
# i :  30000
# train_accuracy :  0.974764
# validation_accuracy :  0.9356
# Model saved in file: ./models/2016-12-09_77_6_model.ckpt
# epoch :  77
# i :  35000
# train_accuracy :  0.975455
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_77_7_model.ckpt
# epoch :  77
# i :  40000
# train_accuracy :  0.975618
# validation_accuracy :  0.9338
# Model saved in file: ./models/2016-12-09_77_8_model.ckpt
# epoch :  77
# i :  45000
# train_accuracy :  0.978418
# validation_accuracy :  0.9374
# Model saved in file: ./models/2016-12-09_77_9_model.ckpt
# epoch :  77
# i :  50000
# train_accuracy :  0.976491
# validation_accuracy :  0.9356
# Model saved in file: ./models/2016-12-09_77_10_model.ckpt
# epoch :  77
# i :  55000
# train_accuracy :  0.968691
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_77_11_model.ckpt
# One epoch finished
# epoch :  77
# train_accuracy :  0.968691
# validation_accuracy :  0.9312
# test_accuracy :  0.9293
# Model saved in file: ./models/2016-12-09_77_0_model.ckpt
# epoch :  78
# i :  5000
# train_accuracy :  0.976691
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_78_1_model.ckpt
# epoch :  78
# i :  10000
# train_accuracy :  0.972237
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_78_2_model.ckpt
# epoch :  78
# i :  15000
# train_accuracy :  0.977928
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_78_3_model.ckpt
# epoch :  78
# i :  20000
# train_accuracy :  0.975018
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_78_4_model.ckpt
# epoch :  78
# i :  25000
# train_accuracy :  0.976909
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_78_5_model.ckpt
# epoch :  78
# i :  30000
# train_accuracy :  0.9744
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_78_6_model.ckpt
# epoch :  78
# i :  35000
# train_accuracy :  0.976291
# validation_accuracy :  0.9362
# Model saved in file: ./models/2016-12-09_78_7_model.ckpt
# epoch :  78
# i :  40000
# train_accuracy :  0.975091
# validation_accuracy :  0.9308
# Model saved in file: ./models/2016-12-09_78_8_model.ckpt
# epoch :  78
# i :  45000
# train_accuracy :  0.978273
# validation_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_78_9_model.ckpt
# epoch :  78
# i :  50000
# train_accuracy :  0.974582
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_78_10_model.ckpt
# epoch :  78
# i :  55000
# train_accuracy :  0.978546
# validation_accuracy :  0.9364
# Model saved in file: ./models/2016-12-09_78_11_model.ckpt
# One epoch finished
# epoch :  78
# train_accuracy :  0.978546
# validation_accuracy :  0.9364
# test_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_78_0_model.ckpt
# epoch :  79
# i :  5000
# train_accuracy :  0.976073
# validation_accuracy :  0.935
# Model saved in file: ./models/2016-12-09_79_1_model.ckpt
# epoch :  79
# i :  10000
# train_accuracy :  0.973382
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_79_2_model.ckpt
# epoch :  79
# i :  15000
# train_accuracy :  0.975637
# validation_accuracy :  0.9306
# Model saved in file: ./models/2016-12-09_79_3_model.ckpt
# epoch :  79
# i :  20000
# train_accuracy :  0.973073
# validation_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_79_4_model.ckpt
# epoch :  79
# i :  25000
# train_accuracy :  0.976146
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_79_5_model.ckpt
# epoch :  79
# i :  30000
# train_accuracy :  0.973018
# validation_accuracy :  0.9348
# Model saved in file: ./models/2016-12-09_79_6_model.ckpt
# epoch :  79
# i :  35000
# train_accuracy :  0.978564
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_79_7_model.ckpt
# epoch :  79
# i :  40000
# train_accuracy :  0.977037
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_79_8_model.ckpt
# epoch :  79
# i :  45000
# train_accuracy :  0.975418
# validation_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_79_9_model.ckpt
# epoch :  79
# i :  50000
# train_accuracy :  0.975546
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_79_10_model.ckpt
# epoch :  79
# i :  55000
# train_accuracy :  0.980237
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_79_11_model.ckpt
# One epoch finished
# epoch :  79
# train_accuracy :  0.980237
# validation_accuracy :  0.934
# test_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_79_0_model.ckpt
# epoch :  80
# i :  5000
# train_accuracy :  0.972018
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_80_1_model.ckpt
# epoch :  80
# i :  10000
# train_accuracy :  0.976546
# validation_accuracy :  0.9338
# Model saved in file: ./models/2016-12-09_80_2_model.ckpt
# epoch :  80
# i :  15000
# train_accuracy :  0.976837
# validation_accuracy :  0.9332
# Model saved in file: ./models/2016-12-09_80_3_model.ckpt
# epoch :  80
# i :  20000
# train_accuracy :  0.975291
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_80_4_model.ckpt
# epoch :  80
# i :  25000
# train_accuracy :  0.979219
# validation_accuracy :  0.9366
# Model saved in file: ./models/2016-12-09_80_5_model.ckpt
# epoch :  80
# i :  30000
# train_accuracy :  0.977273
# validation_accuracy :  0.9322
# Model saved in file: ./models/2016-12-09_80_6_model.ckpt
# epoch :  80
# i :  35000
# train_accuracy :  0.976928
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_80_7_model.ckpt
# epoch :  80
# i :  40000
# train_accuracy :  0.976982
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_80_8_model.ckpt
# epoch :  80
# i :  45000
# train_accuracy :  0.972873
# validation_accuracy :  0.9338
# Model saved in file: ./models/2016-12-09_80_9_model.ckpt
# epoch :  80
# i :  50000
# train_accuracy :  0.978855
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_80_10_model.ckpt
# epoch :  80
# i :  55000
# train_accuracy :  0.978837
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_80_11_model.ckpt
# One epoch finished
# epoch :  80
# train_accuracy :  0.978837
# validation_accuracy :  0.9328
# test_accuracy :  0.9319
# Model saved in file: ./models/2016-12-09_80_0_model.ckpt
# epoch :  81
# i :  5000
# train_accuracy :  0.977782
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_81_1_model.ckpt
# epoch :  81
# i :  10000
# train_accuracy :  0.976546
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_81_2_model.ckpt
# epoch :  81
# i :  15000
# train_accuracy :  0.978291
# validation_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_81_3_model.ckpt
# epoch :  81
# i :  20000
# train_accuracy :  0.971473
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_81_4_model.ckpt
# epoch :  81
# i :  25000
# train_accuracy :  0.978691
# validation_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_81_5_model.ckpt
# epoch :  81
# i :  30000
# train_accuracy :  0.974437
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_81_6_model.ckpt
# epoch :  81
# i :  35000
# train_accuracy :  0.977182
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_81_7_model.ckpt
# epoch :  81
# i :  40000
# train_accuracy :  0.9732
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_81_8_model.ckpt
# epoch :  81
# i :  45000
# train_accuracy :  0.9762
# validation_accuracy :  0.9294
# Model saved in file: ./models/2016-12-09_81_9_model.ckpt
# epoch :  81
# i :  50000
# train_accuracy :  0.977873
# validation_accuracy :  0.932
# Model saved in file: ./models/2016-12-09_81_10_model.ckpt
# epoch :  81
# i :  55000
# train_accuracy :  0.977164
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_81_11_model.ckpt
# One epoch finished
# epoch :  81
# train_accuracy :  0.977164
# validation_accuracy :  0.9346
# test_accuracy :  0.9314
# Model saved in file: ./models/2016-12-09_81_0_model.ckpt
# epoch :  82
# i :  5000
# train_accuracy :  0.976582
# validation_accuracy :  0.9302
# Model saved in file: ./models/2016-12-09_82_1_model.ckpt
# epoch :  82
# i :  10000
# train_accuracy :  0.977146
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_82_2_model.ckpt
# epoch :  82
# i :  15000
# train_accuracy :  0.979891
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_82_3_model.ckpt
# epoch :  82
# i :  20000
# train_accuracy :  0.979091
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_82_4_model.ckpt
# epoch :  82
# i :  25000
# train_accuracy :  0.978964
# validation_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_82_5_model.ckpt
# epoch :  82
# i :  30000
# train_accuracy :  0.976619
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_82_6_model.ckpt
# epoch :  82
# i :  35000
# train_accuracy :  0.973837
# validation_accuracy :  0.9312
# Model saved in file: ./models/2016-12-09_82_7_model.ckpt
# epoch :  82
# i :  40000
# train_accuracy :  0.978437
# validation_accuracy :  0.9318
# Model saved in file: ./models/2016-12-09_82_8_model.ckpt
# epoch :  82
# i :  45000
# train_accuracy :  0.976982
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_82_9_model.ckpt
# epoch :  82
# i :  50000
# train_accuracy :  0.974746
# validation_accuracy :  0.9316
# Model saved in file: ./models/2016-12-09_82_10_model.ckpt
# epoch :  82
# i :  55000
# train_accuracy :  0.979491
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_82_11_model.ckpt
# One epoch finished
# epoch :  82
# train_accuracy :  0.979491
# validation_accuracy :  0.9328
# test_accuracy :  0.9327
# Model saved in file: ./models/2016-12-09_82_0_model.ckpt
# epoch :  83
# i :  5000
# train_accuracy :  0.978055
# validation_accuracy :  0.934
# Model saved in file: ./models/2016-12-09_83_1_model.ckpt
# epoch :  83
# i :  10000
# train_accuracy :  0.979982
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_83_2_model.ckpt
# epoch :  83
# i :  15000
# train_accuracy :  0.978964
# validation_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_83_3_model.ckpt
# epoch :  83
# i :  20000
# train_accuracy :  0.976564
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_83_4_model.ckpt
# epoch :  83
# i :  25000
# train_accuracy :  0.977964
# validation_accuracy :  0.9342
# Model saved in file: ./models/2016-12-09_83_5_model.ckpt
# epoch :  83
# i :  30000
# train_accuracy :  0.977255
# validation_accuracy :  0.9326
# Model saved in file: ./models/2016-12-09_83_6_model.ckpt
# epoch :  83
# i :  35000
# train_accuracy :  0.978364
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_83_7_model.ckpt
# epoch :  83
# i :  40000
# train_accuracy :  0.977455
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_83_8_model.ckpt
# epoch :  83
# i :  45000
# train_accuracy :  0.976928
# validation_accuracy :  0.9352
# Model saved in file: ./models/2016-12-09_83_9_model.ckpt
# epoch :  83
# i :  50000
# train_accuracy :  0.970727
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_83_10_model.ckpt
# epoch :  83
# i :  55000
# train_accuracy :  0.977782
# validation_accuracy :  0.9372
# Model saved in file: ./models/2016-12-09_83_11_model.ckpt
# One epoch finished
# epoch :  83
# train_accuracy :  0.977782
# validation_accuracy :  0.9372
# test_accuracy :  0.9334
# Model saved in file: ./models/2016-12-09_83_0_model.ckpt
# epoch :  84
# i :  5000
# train_accuracy :  0.978619
# validation_accuracy :  0.935
# Model saved in file: ./models/2016-12-09_84_1_model.ckpt
# epoch :  84
# i :  10000
# train_accuracy :  0.978673
# validation_accuracy :  0.9354
# Model saved in file: ./models/2016-12-09_84_2_model.ckpt
# epoch :  84
# i :  15000
# train_accuracy :  0.9736
# validation_accuracy :  0.9328
# Model saved in file: ./models/2016-12-09_84_3_model.ckpt
# epoch :  84
# i :  20000
# train_accuracy :  0.975782
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_84_4_model.ckpt
# epoch :  84
# i :  25000
# train_accuracy :  0.9718
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_84_5_model.ckpt
# epoch :  84
# i :  30000
# train_accuracy :  0.977273
# validation_accuracy :  0.935
# Model saved in file: ./models/2016-12-09_84_6_model.ckpt
# epoch :  84
# i :  35000
# train_accuracy :  0.976691
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_84_7_model.ckpt
# epoch :  84
# i :  40000
# train_accuracy :  0.976928
# validation_accuracy :  0.9358
# Model saved in file: ./models/2016-12-09_84_8_model.ckpt
# epoch :  84
# i :  45000
# train_accuracy :  0.976782
# validation_accuracy :  0.9324
# Model saved in file: ./models/2016-12-09_84_9_model.ckpt
# epoch :  84
# i :  50000
# train_accuracy :  0.973909
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_84_10_model.ckpt
# epoch :  84
# i :  55000
# train_accuracy :  0.980346
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_84_11_model.ckpt
# One epoch finished
# epoch :  84
# train_accuracy :  0.980346
# validation_accuracy :  0.9346
# test_accuracy :  0.9344
# Model saved in file: ./models/2016-12-09_84_0_model.ckpt
# epoch :  85
# i :  5000
# train_accuracy :  0.977691
# validation_accuracy :  0.9356
# Model saved in file: ./models/2016-12-09_85_1_model.ckpt
# epoch :  85
# i :  10000
# train_accuracy :  0.978382
# validation_accuracy :  0.9336
# Model saved in file: ./models/2016-12-09_85_2_model.ckpt
# epoch :  85
# i :  15000
# train_accuracy :  0.974637
# validation_accuracy :  0.9346
# Model saved in file: ./models/2016-12-09_85_3_model.ckpt
# epoch :  85
# i :  20000
# train_accuracy :  0.967382
# validation_accuracy :  0.933
# Model saved in file: ./models/2016-12-09_85_4_model.ckpt

# %%
# trX = trX * 255
# Batch Normalization
# mean_image = np.reshape(np.mean(trX,axis=0),[1,-1])
# trX = (trX - mean_image) # / np.reshape(np.std(trX, axis=0), [1,-1])
